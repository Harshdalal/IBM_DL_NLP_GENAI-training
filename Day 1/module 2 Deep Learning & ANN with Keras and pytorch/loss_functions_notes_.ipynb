# %% [markdown]
# #Loss Function
#
# A loss function is a mathematical function used to measure the error between the predicted output of a model and the actual ground truth.
#
# >The goal of training a machine learning or deep learning model is to minimize the loss function so that the model predictions become more accurate.
#
# #🔝 Top Loss Functions
#
# | Name                      | Use Case                   | Type           |
# | ------------------------- | -------------------------- | -------------- |
# | Mean Squared Error (MSE)  | Regression                 | Regression     |
# | Mean Absolute Error (MAE) | Regression                 | Regression     |
# | Binary Cross Entropy      | Binary classification      | Classification |
# | Categorical Cross Entropy | Multi-class classification | Classification |
# | Hinge Loss                | SVM-style classification   | Classification |
#
# #🔢 1. Mean Squared Error (MSE)
#
# Measures the average of squared differences between actual and predicted values.
#
# 📘 Equation:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

def mse(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %% [markdown]
# #🔢 2. Root Mean Squared Error (RMSE)
#
# Square root of MSE; provides error in the same units as the target.
#
# 📘 Equation:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred) ** 2))

# %% [markdown]
# #🔢 3. Mean Absolute Error (MAE)
#
# 📘 Definition: Measures the average of absolute differences between actual and predicted values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def mae(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

# %% [markdown]
# #📌 Classification Losses:
# Used when output is categorical (class labels).

# %% [markdown]
# #🔢 4. Binary Cross Entropy (Log Loss)
#
# 📘 Definition: Measures error for binary classification where output is a probability (0 to 1).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def binary_cross_entropy(y_true, y_pred, eps=1e-15):
    y_pred = np.clip(y_pred, eps, 1 - eps)
    return -np.mean(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))

# %% [markdown]
# #🔢 5. Categorical Cross Entropy (CCE)
# 📘 Definition: Used in multi-class classification (typically with softmax outputs).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def categorical_cross_entropy(y_true, y_pred, eps=1e-15):
    y_pred = np.clip(y_pred, eps, 1 - eps)
    return -np.sum(y_true * np.log(y_pred)) / y_true.shape[0]

# %% [markdown]
# #🔢 6. Hinge Loss
# 📘 Definition: Used with Support Vector Machines; penalizes wrong classifications with a margin.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def hinge_loss(y_true, y_pred):
    return np.mean(np.maximum(0, 1 - y_true * y_pred))

# %% [markdown]
# #🔬 Visualizing MSE, MAE, RMSE Comparison

# %%
import matplotlib.pyplot as plt

errors = np.linspace(-2, 2, 100)
mse_vals = errors ** 2
mae_vals = np.abs(errors)
rmse_vals = np.sqrt(mse_vals)

plt.plot(errors, mse_vals, label='MSE')
plt.plot(errors, mae_vals, label='MAE')
plt.plot(errors, rmse_vals, label='RMSE', linestyle='--')
plt.title("MSE vs MAE vs RMSE")
plt.xlabel("Error")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #📊 Final Summary Table
#
# | Loss Function                 | Use Case                   | Output Type   | Outlier Sensitivity | Notes                        |
# | ----------------------------- | -------------------------- | ------------- | ------------------- | ---------------------------- |
# | **MSE**                       | Regression                 | Continuous    | ✅ High              | Penalizes large errors more  |
# | **RMSE**                      | Regression                 | Continuous    | ✅ High              | Same units as target         |
# | **MAE**                       | Regression                 | Continuous    | ❌ Low               | Linear error penalty         |
# | **Binary Cross Entropy**      | Binary classification      | Probabilities | ✅ High              | Requires sigmoid output      |
# | **Categorical Cross Entropy** | Multi-class classification | Probabilities | ✅ High              | Requires softmax output      |
# | **Hinge Loss**                | Binary/SVM classification  | {-1, +1}      | ⚠️ Medium           | Used with margin classifiers |
