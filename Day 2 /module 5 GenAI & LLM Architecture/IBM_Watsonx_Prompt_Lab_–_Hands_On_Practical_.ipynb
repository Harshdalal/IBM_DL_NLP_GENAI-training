# %% [markdown]
# #IBM Watsonx Prompt Lab – Hands-On Practical (Beginner to Intermediate)
#
# Duration: 10 minutes
# Tools: Only watsonx.ai → Prompt Lab (no coding required)

# %% [markdown]
# #Practical Overview
#
# In this lab, learners will:
#
# 1.Select different LLMs (Granite, Mistral, Llama)
#
# 2.Test 5 core Prompt Engineering techniques
#
# 3.Compare outputs visually
#
# 4.Export code (Python) from Prompt Lab
#
# 5.Document observations
#
# This is 100% no-code and uses only Prompt Lab.

# %% [markdown]
# #TASK 1 — Open Prompt Lab & Select Model
# Steps:
#
# 1.Open watsonx.ai → Prompt Lab
#
# 2.At the top-left, choose the model:
#
# >granite-4-h-small (baseline)
#
# 3.Set Temperature = 0.2
#
# 4.Set Max tokens = 250
#
# #TASK 2 — Zero-Shot Prompting
# Prompt:
# ```
# Explain what blockchain is.
# ```
#
# Expected Learning:
#
# Model gives generic explanation
#
# No structure
#
# Sometimes vague or inconsistent
#
# Student Action:
#
# ✔ Write 1–2 lines: “Output quality, clarity, missing details…”
#
# #TASK 3 — Instruction Prompting
#
# Change the prompt:
#
# ```
# You are an expert technology trainer.
# Explain blockchain in simple words and give one real-life example.
# ```
#
# Expected:
#
# Structured
#
# Simpler language
#
# More useful output
#
# Student Action:
#
# ✔ Compare with Zero-Shot
# ✔ Note 2 improvements
#
# #TASK 4 — Few-Shot Prompting
#
# Click Add Variation.
#
# Use this prompt:
# ```
# Explain a complex technology concept in simple words.
#
# Example 1:
# Topic: Neural Networks
# Output: Neural networks learn patterns by adjusting connections.
#
# Example 2:
# Topic: Internet of Things
# Output: IoT means devices talking to each other and sharing data.
#
# Now follow the same style.
# Topic: Blockchain
# Output:
# ```
#
# Expected:
#
# Model follows examples
#
# Produces consistent formatting
#
# Better clarity
#
# Student Action:
#
# ✔ Write what changed compared to Instruction Prompting.
#
# #TASK 5 — Chain-of-Thought Reasoning
#
# Add another variation.
#
# Prompt:
# ```
# Explain blockchain step-by-step. Think through the explanation before answering.
# ```
# Expected:
#
# More reasoning steps
#
# Sequential explanation
#
# Clear flow
#
# Student Action:
#
# ✔ Identify the step-by-step improvement
# ✔ Note whether reasoning is logical
#
# #TASK 6 — Role Prompt + Constraints
#
# Add another variation.
#
# Prompt:
# ```
# Act as an IBM cloud architect.
# Explain how blockchain helps supply-chain operations.
# Use exactly:
# - 3 bullet points
# - 1 diagram-style line
# - Keep answer under 120 words
# ```
#
# Expected:
#
# Structured output
#
# Follows constraints
#
# More professional viewpoint
#
# Student Action:
#
# ✔ Check: Did model follow constraints?
# ✔ If not, adjust prompt and try again.
#
# #TASK 7 — Compare All Variations
#
# Use Prompt Lab’s side-by-side comparison.
#
# Compare:
#
# > Zero-shot
#
# > Instruction
#
# > Few-shot
#
# > Chain-of-Thought
#
# > Role-based
#
# #Student Action:
#
# ✔ Fill table:
#
# | Technique   | Best Strength | Weakness | Output Quality (1–5) |
# | ----------- | ------------- | -------- | -------------------- |
# | Zero-shot   |               |          |                      |
# | Instruction |               |          |                      |
# | Few-shot    |               |          |                      |
# | CoT         |               |          |                      |
# | Role Prompt |               |          |                      |

# %% [markdown]
# #TASK 8 — Export Code
#
# On any prompt, click:
#
# 👉 View Code → Python
#
# Student Action:
#
# ✔ Copy the generated code
#
# ✔ Paste it into a Jupyter Notebook
#
# ✔ Identify:
#
# Model ID
#
# Token settings
#
# Temperature
#
# Prompt text
#
# #TASK 9 — Change the Model & Compare Outputs
#
# Switch to:
#
# 1.mistral-small-3-1-24b-instruct
#
# 2.llama-3-3-70b-instruct
#
# Re-run the same prompts.
#
# #Student Action:
#
# ✔ Write differences:
#
# > Which is more detailed?
#
# > Which follows constraints?
#
# > Which is faster?
#
# > Which is more factual?
#
# #TASK 10 — Final Reflection
#
# Students write:
#
# 1.Which prompt technique gave the best output?
#
# 2.Which model gave the best results?
#
# 3.What is your best final prompt?
#
# 4.How would you improve it?
#
# #🎉Practical Completed
#
# This exercise teaches:
#
# Prompt engineering fundamentals
#
# Model behavior differences
#
# Constraint & role prompting
#
# How to test prompts in enterprise environment
#
# How to export code for production use
