# %% [markdown]
# #Deep Learning: Evolution, Meaning, Neural Networks & Tools
#
# #📈 1. Evolution of Deep Learning from AI and ML
#
# >🧠 Artificial Intelligence (AI)
#
# Definition: AI is the broader field concerned with creating intelligent agents that can perform tasks mimicking human intelligence.
#
# Goal: Emulate human reasoning, learning, problem-solving, and perception.
#
# AI ⟶ Machine Learning ⟶ Deep Learning
#
# >📊 Machine Learning (ML)
#
# Subset of AI
#
# Definition: Algorithms that allow machines to learn from data and improve over time without being explicitly programmed.
#
# Key Concepts:
#
# >Supervised Learning: Learn from labeled data
#
# >Unsupervised Learning: Find patterns in unlabeled data
#
# >Reinforcement Learning: Learn via reward-based feedback
#
# 🤖 Deep Learning (DL)
#
# >Subset of ML
#
# >Uses Artificial Neural Networks (ANNs) inspired by human brain structure
#
# >Handles high-dimensional, unstructured data (e.g., images, audio, text)
#
# #📌 Evolution Summary Table:
#
# | Field | Description                   | Examples                         |
# | ----- | ----------------------------- | -------------------------------- |
# | AI    | Mimics human cognition        | Chess-playing agent, Siri        |
# | ML    | Data-driven learning          | Spam detection, fraud detection  |
# | DL    | Multi-layered neural networks | Face recognition, speech-to-text |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #🧬 2. Meaning & Definition of Deep Learning (With Case Study)
# 🔍 Definition:
#
# >Deep Learning is a class of ML algorithms that use multiple layers of non-linear processing units for feature extraction and transformation. Each successive layer uses the output from the previous one.
#
# #🧮 General Form of a Neural Network:
# Given an input vector x, the output of a neural network layer is:
#
#                       h=σ(Wx+b)
#
# 𝑊: weight matrix
#
# 𝑏: bias vector
#
# 𝜎: activation function (like ReLU, sigmoid)
#
# ℎ: output of the layer
#
# #📚 Case Study: Image Classification Using Deep Learning
# Problem:
#
# Classify images of cats and dogs using a dataset (e.g., Kaggle Dogs vs Cats dataset).
#
# Approach:
#
# 1.Data Input: Raw pixel values (e.g., 224×224×3 for RGB images)
#
# 2.Architecture: Convolutional Neural Network (CNN)
#
# 3.Layers:
#
# >Convolution → Activation (ReLU) → Pooling → Fully Connected → Softmax
#
# 4.Output: Probability distribution over [Cat, Dog]
#
# Result:
#
# > Accuracy of 95%+ achievable using transfer learning (e.g., ResNet, VGG).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #🧠 3. Neural Networks: Meaning, Process & Types
# 🧠 Biological Inspiration:
#
# Neuron (Biological):
#
# >Dendrites receive signals
#
# >Axon transmits the signal
#
# >Synapse passes signal to next neuron

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #💻 Artificial Neuron (Perceptron):
#
# #⚙️ Equation:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #🔄 Deep Learning Process:
# 1.Forward Propagation: Data flows from input to output
#
# 2.Loss Calculation: Compare predicted output with actual label
#
# 3.Backpropagation: Calculate gradients using chain rule
#
# 4.Optimization: Use algorithms like SGD, Adam to minimize loss

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #🧠 Types of Neural Networks:
#
# | Type            | Description                           | Applications                |
# | --------------- | ------------------------------------- | --------------------------- |
# | **ANN**         | Basic dense layers                    | Tabular data, regression    |
# | **CNN**         | 2D convolution for spatial data       | Image classification        |
# | **RNN**         | Recurrent structure for sequence data | Time-series, NLP            |
# | **LSTM/GRU**    | Advanced RNNs with memory             | Sentiment analysis, speech  |
# | **GAN**         | Two competing networks                | Image synthesis, deep fakes |
# | **Transformer** | Attention-based sequence learning     | Translation, Chatbots       |

# %% [markdown]
# #🧠 Neural Networks vs Human Neurons
#
# | Feature      | Human Neurons         | Artificial Neurons      |
# | ------------ | --------------------- | ----------------------- |
# | Structure    | Complex bio-structure | Simple weighted sum     |
# | Processing   | Electro-chemical      | Mathematical operations |
# | Learning     | Neuroplasticity       | Gradient Descent        |
# | Speed        | Slower                | Faster computation      |
# | Adaptability | Lifelong learning     | Needs retraining        |
#
# #🛠️ 4. Deep Learning Platforms & Programming Stacks
# #🧰 Programming Languages:
#
# Python (most widely used)
#
# R
#
# Julia
#
# C++
#
# #📦 Libraries and Frameworks:
#
# | Framework      | Language   | Features                             |
# | -------------- | ---------- | ------------------------------------ |
# | **TensorFlow** | Python/C++ | Google's DL framework, scalable      |
# | **PyTorch**    | Python     | Dynamic graphs, easy debugging       |
# | **Keras**      | Python     | High-level wrapper for TensorFlow    |
# | **MXNet**      | Python/C++ | Scalable, used by AWS                |
# | **JAX**        | Python     | Google’s fast ML library for GPU/TPU |
# | **ONNX**       | N/A        | Interoperability across frameworks   |
