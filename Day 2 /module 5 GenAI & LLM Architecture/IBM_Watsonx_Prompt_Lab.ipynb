# %% [markdown]
# #What is IBM Watsonx Prompt Lab?
#
# Prompt Lab is a no-code playground inside watsonx.ai where you can:
#
# > Test different LLMs (Granite, Llama, Mistral, etc.)
#
# > Try prompt techniques (zero-shot, few-shot, role prompts…)
#
# > Upload documents for RAG experiments
#
# > Adjust temperature, token size, decoding settings
#
# > Compare multiple prompts quickly
#
# > Export code (Python, cURL, JS) to use in your project
#
# It is the BEST place to experiment before writing code.

# %% [markdown]
# #HOW TO OPEN PROMPT LAB
#
# Step 1 — Log in to IBM Cloud
#
# https://cloud.ibm.com
#
# Step 2 — Open watsonx.ai
#
# On left menu: AI / Machine Learning → watsonx.ai
#
# Or directly: https://dataplatform.cloud.ibm.com/wx/home
#
# Step 3 — Go to "Prompt Lab"
#
# Inside watsonx.ai:
#
# Click "Generate" → "Prompt Lab"
#
# That’s it. You are inside the prompt playground.

# %% [markdown]
# #HOW TO USE PROMPT LAB (Simple Workflow)
# #STEP 1 — Choose Your Model
#
# At the top-left, select:
#
# granite-4-h-small
#
# granite-8b-code-instruct
#
# mistral-small-24b
#
# llama-3-3-70b-instruct
#
# llama-3-vision
#
# gpt-oss-120b
#
# etc.
#
# Pick one model depending on your need:
#
# > Fast & cheap = Granite small
#
# > Coding = Granite code instruct
#
# > High quality = Llama-3-70B
#
# > Vision = Llama Vision models
#
# #STEP 2 — Write Your Prompt
#
# Area center page → type your text.
#
# Examples:
# ```
# Explain blockchain in simple words.
#
# ```
# Or try a more advanced prompt:
#
# ```
# Act like a cloud expert. Explain blockchain for supply chain in 3 bullets.
# ```
#
# #STEP 3 — Adjust Settings
#
# Right side panel:
#
# Temperature → creativity
#
# Max token limit → length of answer
#
# Top-p / Top-k → decoding quality
#
# For consistent results:
#
# Temp = 0.2–0.3
#
# #STEP 4 — Click "Generate"
#
# You get the result instantly.
#
# Compare Prompts Quickly
#
# Prompt Lab allows prompt variants.
#
# Click:
# 👉 “Add Variation”
#
# #You can test:
#
# Prompt A (zero-shot)
#
# Prompt B (few-shot)
#
# Prompt C (role prompt)
#
# Then compare outputs side-by-side.
#
# #Try Prompt Engineering Techniques
#
# You can test all types visually:
#
# Zero-shot
# ```
# Explain blockchain.
# ```
#
# Few-shot
#
# ```
# Example 1:
# Input: Neural networks
# Output: Neural networks learn patterns...
#
# Example 2:
# Input: IoT
# Output: IoT devices talk to each other...
#
# Now do the same for Blockchain.
# ```
#
# Chain-of-thought
# ```
# Explain step-by-step how blockchain works.
# ```
#
# Role prompt
# ```
# Act like an IBM architect. Explain blockchain in 100 words.
# ```
#
# #View / Export Code
#
# After generating a prompt:
#
# 👉 Click “View Code”
#
# >You get auto-generated code for:
#
# Python
#
# cURL
#
# JavaScript
#
# Perfect for using inside Jupyter or your backend app.

# %% [markdown]
# #Testing RAG (Retrieval Augmented Generation)
#
# Prompt Lab also supports:
#
# > Uploading documents (PDF, TXT)
#
# > Using "Prompt + Context" mode
#
# > Asking questions based on your uploaded files
#
# Steps:
#
# 1.In Prompt Lab → choose "Upload Document"
#
# 2.Ask:
# ```
# Summarize this document.
# ```
#
# 3.Or:
# ```
# What are the key policies mentioned?
# ```
#
# #Save & Share Prompts
#
# Click Save
#
# You can share prompt templates with team members
#
# Perfect for enterprise projects.
#
# #When to Move From Prompt Lab to Code
#
# Once your prompt looks good:
#
# Click View Code
#
# Copy the Python code
#
# Paste into your notebook
#
# Replace API key + endpoint
#
# Done
#
# This avoids testing everything in code manually.
