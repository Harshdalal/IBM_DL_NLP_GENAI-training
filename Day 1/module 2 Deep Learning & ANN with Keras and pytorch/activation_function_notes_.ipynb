# %% [markdown]
# #Activation Function
#
# An activation function adds non-linearity to neural networks and helps them learn complex patterns.
#
# It transforms the input signal to an output signal — often squashing it into a range like [0,1] or [-1,1].
#
# #🔝 Top Activation Functions
#
# | Name       | Output Range | Use Case                            |
# | ---------- | ------------ | ----------------------------------- |
# | Sigmoid    | (0, 1)       | Binary classification (output)      |
# | Tanh       | (-1, 1)      | Hidden layers, better than Sigmoid  |
# | ReLU       | \[0, ∞)      | Hidden layers in deep networks      |
# | Leaky ReLU | (-∞, ∞)      | Like ReLU, but handles "dying ReLU" |
# | Softmax    | \[0, 1]      | Multiclass classification (output)  |
#
#
# # 1. Sigmoid Function
# Equation:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %% [markdown]
# #📘 2. Tanh (Hyperbolic Tangent)
# Equation:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def tanh(x):
    return np.tanh(x)

# %% [markdown]
# #📘 3. ReLU (Rectified Linear Unit)
# Equation:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def relu(x):
    return np.maximum(0, x)

# %% [markdown]
# #📘 4. Leaky ReLU
# Equation:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def leaky_relu(x, alpha=0.01):
    return np.where(x > 0, x, alpha * x)

# %% [markdown]
# #📘 5. Softmax
# Used in output layer of multi-class classification.
#
# Equation:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def softmax(x):
    exp_x = np.exp(x - np.max(x))  # Stability trick
    return exp_x / exp_x.sum(axis=0)

# %% [markdown]
# #📊 Visual Comparison

# %%
x = np.linspace(-10, 10, 100)

plt.figure(figsize=(12, 6))
plt.plot(x, sigmoid(x), label='Sigmoid')
plt.plot(x, tanh(x), label='Tanh')
plt.plot(x, relu(x), label='ReLU')
plt.plot(x, leaky_relu(x), label='Leaky ReLU')
plt.plot(x, softmax(x), label='Softmax (normalized)', linestyle='--')

plt.title("Activation Functions")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #✅ Summary Table
#
# | Function       | Range   | Notes                               |
# | -------------- | ------- | ----------------------------------- |
# | **Sigmoid**    | (0, 1)  | Used in binary output               |
# | **Tanh**       | (-1, 1) | Zero-centered, better than sigmoid  |
# | **ReLU**       | \[0, ∞) | Fast, popular in deep learning      |
# | **Leaky ReLU** | (-∞, ∞) | Fixes ReLU "dying" neuron problem   |
# | **Softmax**    | \[0, 1] | Probabilities for multiclass output |
